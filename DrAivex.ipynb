# %%
import numpy as np
import pandas as pd

# %%
location=r'C:\Users\amar kumar soni\Desktop\pandas\dataset.xlsx'
df=pd.read_excel(location)
df
# Out:
#                       Name                            Email Year Department
# 0           Tiyasa Bhaumik        tiyasabhaumik80@gmail.com  3rd         EE
# 1       Neha Sarbadhikary      sarbadhikaryneha70@gmail.com  3rd         EE
# 2         Shankhadeep Giri   shankhadeepgiri.nsec@gmail.com  2nd        CSE
# 3             Debangan Das           das.debangan@gmail.com  3rd        CSE
# 4                Faiz Alam             faiz276482@gmail.com  2nd         IT
# 5           Abhishek kumar           abhishek3368@gmail.com  2nd         IT
# 6               Vishwajeet             vish260199@gmail.com  2nd        CSE
# 7            Pradeep Kumar          pradeeproy732@gmail.com  2nd         IT
# 8              Vivek Kumar      sonusingh29051998@gmail.com  2nd        CSE
# 9          Tanmoy Sengupta          tasengupta405@gmail.com  2nd         EE
# 10           Gourab Santra   sabujgourabsantra123@gmail.com  2nd         EE
# ...

# %%
mech=df[df['Department']=='ME']
civil=df[df['Department']=='CE']
Year_3rd=df[df['Year']=='3rd']
Nm = Year_3rd['Name'].str.split()
email=Year_3rd['Email'].str.split()

# %%
j=0
for index,row in Year_3rd.iterrows():
    
    if(Nm[index][0].lower() in email[index][0].lower()) or (Nm[index][1].lower() in email[index][0].lower()):
        j=j+1

# %%
C=civil['Name'].count()
M=mech['Name'].count()

# %%
p=Year_3rd['Name'].count()

# %%
p
# Out:
# 19

# %%
#for calculating percentage
tot=df['Name'].count()

# %%
tot
# Out:
# 99

# %%
per=((M+C)/tot)*100
per
# Out:
# 0.0

# %%
#for finding the existance of DrAivex
D=tot-j
D
# Out:
# 82

# %%
if (D>30) and (per>10) :
    print("there is Existance of DrAivex")
else :
    print("there is no Existance of DrAivex")
# Out:
# there is no Existance of DrAivex
